# %% [markdown]
# ## Day 4 ML Class

# %%
import pandas as pd

# %%
import requests

# %% [markdown]
# ## Api key import

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=bd5b4df36bd91e5661008e60388cda6f&langage=en-US&page=1')

# %% [markdown]
# ### 6 Column Select Code

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %% [markdown]
# ### Df show

# %%
df
# Out:
#          id                                          title release_date  \
# 0       278                       The Shawshank Redemption   1994-09-23
# 1       238                                  The Godfather   1972-03-14
# 2       240                          The Godfather Part II   1974-12-20
# 3       424                               Schindler's List   1993-12-15
# 4       389                                   12 Angry Men   1957-04-10
# 5     19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 6       129                                  Spirited Away   2001-07-20
# 7       155                                The Dark Knight   2008-07-16
# 8    496243                                       Parasite   2019-05-30
# 9       497                                 The Green Mile   1999-12-10
# 10   372058                                     Your Name.   2016-08-26
# 11      680                                   Pulp Fiction   1994-09-10
# ...

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  vote_average
# 0  Imprisoned in the 1940s for the double murder ...     141.956         8.705
# 1  Spanning the years 1945 to 1955, a chronicle o...     167.366         8.693
# 2  In the continuing saga of the Corleone crime f...     119.775         8.600
# 3  The true story of how businessman Oskar Schind...      94.075         8.568
# 4  The defense and the prosecution have rested an...      80.012         8.545

# %% [markdown]
# ## get a data from page 5

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=bd5b4df36bd91e5661008e60388cda6f&langage=en-US&page=5')

# %%
df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df1
# Out:
#         id                                              title release_date  \
# 0   652837                      Josee, the Tiger and the Fish   2020-12-25
# 1    25237                                       Come and See   1985-10-17
# 2    10376                                 The Legend of 1900   1998-10-28
# 3     8587                                      The Lion King   1994-06-24
# 4      670                                             Oldboy   2003-11-21
# 5   630566                                             Clouds   2020-10-09
# 6   299534                                  Avengers: Endgame   2019-04-24
# 7   283566             Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08
# 8   508965                                              Klaus   2019-11-08
# 9   533514                       Violet Evergarden: The Movie   2020-09-18
# 10  299536                             Avengers: Infinity War   2018-04-25
# ...

# %%
df1.shape
# Out:
# (20, 6)

# %%
df1.to_csv('movies.csv')

# %%
df1
# Out:
#         id                                              title release_date  \
# 0   652837                      Josee, the Tiger and the Fish   2020-12-25
# 1    25237                                       Come and See   1985-10-17
# 2    10376                                 The Legend of 1900   1998-10-28
# 3     8587                                      The Lion King   1994-06-24
# 4      670                                             Oldboy   2003-11-21
# 5   630566                                             Clouds   2020-10-09
# 6   299534                                  Avengers: Endgame   2019-04-24
# 7   283566             Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08
# 8   508965                                              Klaus   2019-11-08
# 9   533514                       Violet Evergarden: The Movie   2020-09-18
# 10  299536                             Avengers: Infinity War   2018-04-25
# ...
